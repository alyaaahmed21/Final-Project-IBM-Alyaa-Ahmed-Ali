# %% [markdown]
# <center><h1>Capstone Project Creation</h1></center>
# <center><h3>IBM SkillsBuild Europe Delivery - Data Analytics</h3></center>
#
#
# # Pre-requisite
#
# * Understanding of Python, Power BI or Tableau
# * Understanding of Data Cleaning
# * Understanding Data Visualization
#
# #### Level of Exercise: Intermediate
#
# #### Duration: approximately 3 hours

# %% [markdown]
# ### Data Analytics of Airbnb Data:
#
# #### Objective:
#
# In this exericise, you will be performing Data Analytics on an Open Dataset dataset coming from Airbnb. Some of the tasks include
# - Data Cleaning.
# - Data Transformation
# - Data Visualization.
#
# #### Overview of Airbnb Data:
#
# People's main criteria when visiting new places are reasonable accommodation and food. Airbnb (Air-Bed-Breakfast) is an online marketplace created to meet this need of people by renting out their homes for a short term. They offer this facility at a relatively lower price than hotels. Further people worldwide prefer the homely and economical service offered by them. They offer services across various geographical locations
#
# #### Dataset Source
#
# YOu can get the dataset for this assessment using the following link: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
#
# This dataset contains information such as the neighborhood offering these services, room type, price,avaliabilty, reviews, service fee, cancellation policy and rules to use the house. This analysis will help airbnb in improving its services.
#
# So all the best for your Data Analytics Journey on Airbnb data!!!

# %% [markdown]
# ## Task 1: Data Loading (Python)
#
# 1. Read the csv file and load it into a pandas dataframe.
# 2. Display the first five rows of your dataframe.
# 3. Display the data types of the columns.

# %%
## Read the csv file
import pandas as pd
df = pd.read_csv('Airbnb_Open_data.csv')
# Out:
# C:\Users\alyaa\AppData\Local\Temp\ipykernel_12100\3876031162.py:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Airbnb_Open_data.csv')

# %%
## Display the first 5 rows
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
## Display the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %% [markdown]
# ## Task 2a: Data Cleaning (Any Tool)
#
# 1. Drop some of the unwanted columns. These include `host id`, `id`, `country` and `country code` from the dataset.
# 2. State the reason for not including these columns for your Data Analytics.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots before and after the elimination of the columns.

# %%
df = df.drop(['host id','id','country','country code'], axis = 1)

# %%
df.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365', 'house_rules',
#        'license'],
#       dtype='object')

# %%
## the resons: The purpose of the dataset focused on specific aspects of the Airbnb platform, such as pricing trends, 
##reviews, or property features, and including host ID, ID, country, or country code may not be relevant to the analytical goals.

# %%
df.shape
# Out:
# (102599, 22)

# %% [markdown]
# ## Task 2b: Data Cleaning (Python)
#
# - Check for missing values in the dataframe and display the count in ascending order. **If the values are missing, impute the values as per the datatype of the columns.**
# - Check whether there are any duplicate values in the dataframe and, if present, remove them.
# - Display the total number of records in the dataframe before and after removing the duplicates.

# %%
df.isna().sum().sort_values(ascending=True)
# Out:
# room type                              0
# lat                                    8
# long                                   8
# neighbourhood                         16
# neighbourhood group                   29
# cancellation_policy                   76
# instant_bookable                     105
# number of reviews                    183
# Construction year                    214
# price                                247
# NAME                                 250
# service fee                          273
# host_identity_verified               289
# calculated host listings count       319
# review rate number                   326
# host name                            406
# minimum nights                       409
# availability 365                     448
# reviews per month                  15879
# last review                        15893
# house_rules                        52131
# license                           102597
# dtype: int64

# %%
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
# Out:
# C:\Users\alyaa\AppData\Local\Temp\ipykernel_12100\254186259.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$','')

# %%
df['price'] = df['price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NAME                            102349 non-null  object
#  1   host_identity_verified          102310 non-null  object
#  2   host name                       102193 non-null  object
#  3   neighbourhood group             102570 non-null  object
#  4   neighbourhood                   102583 non-null  object
#  5   lat                             102591 non-null  float64
#  6   long                            102591 non-null  float64
#  7   instant_bookable                102494 non-null  object
#  8   cancellation_policy             102523 non-null  object
#  9   room type                       102599 non-null  object
#  10  Construction year               102385 non-null  float64
# ...

# %%
numeric_columns = ['lat','long','number of reviews', 'price', 'minimum nights','availability 365','calculated host listings count','reviews per month','Construction year']
for i in numeric_columns:
    df[i] = df[i].fillna( df[i].mean())

# %%
df.isna().sum().sort_values(ascending=True)
# Out:
# Construction year                      0
# availability 365                       0
# calculated host listings count         0
# lat                                    0
# long                                   0
# room type                              0
# reviews per month                      0
# price                                  0
# number of reviews                      0
# minimum nights                         0
# neighbourhood                         16
# neighbourhood group                   29
# cancellation_policy                   76
# instant_bookable                     105
# NAME                                 250
# service fee                          273
# host_identity_verified               289
# review rate number                   326
# host name                            406
# last review                        15893
# house_rules                        52131
# license                           102597
# dtype: int64

# %%
object_columns = ['neighbourhood','neighbourhood group','cancellation_policy','instant_bookable','instant_bookable','instant_bookable','service fee','host_identity_verified','review rate number','host name','last review','NAME']
for i in object_columns:
    df[i] = df[i].fillna( df[i].mode()[0])

# %%
df.isna().sum().sort_values(ascending=True)
# Out:
# NAME                                   0
# availability 365                       0
# calculated host listings count         0
# review rate number                     0
# reviews per month                      0
# last review                            0
# number of reviews                      0
# minimum nights                         0
# service fee                            0
# price                                  0
# Construction year                      0
# room type                              0
# cancellation_policy                    0
# instant_bookable                       0
# long                                   0
# lat                                    0
# neighbourhood                          0
# neighbourhood group                    0
# host name                              0
# host_identity_verified                 0
# house_rules                        52131
# license                           102597
# dtype: int64

# %%
df.drop(['house_rules','license'], axis = 1, inplace = True)

# %%
df.isna().sum().sort_values(ascending=True)
# Out:
# NAME                              0
# review rate number                0
# reviews per month                 0
# last review                       0
# number of reviews                 0
# minimum nights                    0
# service fee                       0
# price                             0
# Construction year                 0
# room type                         0
# cancellation_policy               0
# instant_bookable                  0
# long                              0
# lat                               0
# neighbourhood                     0
# neighbourhood group               0
# host name                         0
# host_identity_verified            0
# calculated host listings count    0
# availability 365                  0
# dtype: int64

# %%
## Check whether there are any duplicate values in the dataframe and if present remove them.
df.duplicated().sum()
df.drop_duplicates(inplace = True)

# %%
## Display the total number of records in the dataframe after removing the duplicates.
df.shape
# Out:
# (98971, 20)

# %% [markdown]
# ## Task 3: Data Transformation (Any Tool)
#
#
# - Rename the column `availability 365` to `days_booked`
# - Convert all column names to lowercase and replace the spaces in the column names with an underscore "_".
# - Remove the dollar sign and comma from the columns `price` and `service_fee`. If necessary, convert these two columns to the appropriate data type.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## Rename the column.
df = df.rename(columns = {'availability 365':'days_booked'})
df.columns
# Out:
# Index(['NAME', 'host_identity_verified', 'host name', 'neighbourhood group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'days_booked'],
#       dtype='object')

# %%
## Convert all column names to lowercase and replace the spaces with an underscore "_"
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room_type', 'construction_year', 'price',
#        'service_fee', 'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'days_booked'],
#       dtype='object')

# %%
## Remove the dollar sign and comma from the columns. If necessary, convert these two columns to the appropriate data type.
## i did it for price column above
## for service fee
df['service_fee']= df['service_fee'].str.strip('$').str.replace(',', '')
df['service_fee'] = df['service_fee'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98971 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            98971 non-null  object
#  1   host_identity_verified          98971 non-null  object
#  2   host_name                       98971 non-null  object
#  3   neighbourhood_group             98971 non-null  object
#  4   neighbourhood                   98971 non-null  object
#  5   lat                             98971 non-null  float64
#  6   long                            98971 non-null  float64
#  7   instant_bookable                98971 non-null  bool
#  8   cancellation_policy             98971 non-null  object
#  9   room_type                       98971 non-null  object
#  10  construction_year               98971 non-null  float64
#  11  price                           98971 non-null  float64
# ...

# %% [markdown]
# ### Task 4: Exploratory Data Analysis (Any Tool)
#
# - List the count of various room types avaliable in the dataset.
# - Which room type has the most strict cancellation policy?
# - List the average price per neighborhood group, and highlight the most expensive neighborhood to rent from.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## List the count of various room types avaliable with Airbnb
df['room_type'].value_counts()
# Out:
# Entire home/apt    51916
# Private room       44797
# Shared room         2143
# Hotel room           115
# Name: room_type, dtype: int64

# %%
## Which room type adheres to more strict cancellation policy
room_type_counts = df[df['cancellation_policy'] == 'strict'].groupby('room_type').size()

# %%
room_type_counts
# Out:
# room_type
# Entire home/apt    17214
# Hotel room            34
# Private room       14905
# Shared room          717
# dtype: int64

# %%
## List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
prices_by_neighborhood = df.groupby('neighbourhood_group')['price'].mean()
prices_by_neighborhood 
most_expensive_group = prices_by_neighborhood.idxmax()
most_expensive_group
# Out:
# 'Queens'

# %% [markdown]
# ## Task 5a: Data Visualization (Any Tool)
#
# * List the count of various room types avaliable with Airnb
# * Which room type adheres to more strict cancellation policy
# * List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
# * List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood.
# * List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph
# * List the prices with respect to room type using a bar graph and also state your inferences.
# * Create a pie chart that shows  distribution of booked days for each neighborhood group .Which neighborhood has the highest booking percentage.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
import matplotlib.pyplot as plt

# %%
df['room_type'].value_counts().plot(kind='bar', color='coral')
plt.title('Count of Various Room Types on Airbnb')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %%
df[df['cancellation_policy'] == 'strict']['room_type'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('room type adheres to more strict cancellation policy')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %%
plt.bar(df.groupby('neighbourhood_group')['price'].mean().reset_index()['neighbourhood_group'], df.groupby('neighbourhood_group')['price'].mean().reset_index()['price'], color='skyblue')
plt.title('Average Prices For Each Neighbourhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Price')
plt.show()

# %%
most_expensive_group = df.groupby('neighbourhood_group')['price'].mean().idxmax()
most_expensive_group
# Out:
# 'Queens'

# %%
plt.barh(df.sort_values(by='price').head(10)['neighbourhood'], df.sort_values(by='price').head(10)['price'], color='lightcoral')
plt.title('Top 10 Neighborhoods')
plt.xlabel('Average Price')
plt.ylabel('Neighborhood')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[df['days_booked'] == 10]['neighbourhood'], df[df['days_booked'] == 10]['days_booked'], color='green')
plt.title('Neighborhoods Offering Short-term Rentals within 10 Days on Airbnb')
plt.xlabel('Neighborhood')
plt.ylabel('days_booked')
plt.show()

# %%
df.groupby('room_type')['price'].mean().sort_values().plot(kind='bar', color='RoyalBlue')
plt.title('Average Prices with Respect to Room Type on Airbnb')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %%
total_booked_days = df.groupby('neighbourhood_group')['days_booked'].sum()
booking_percentage = total_booked_days / total_booked_days.sum() * 100
plt.figure(figsize=(8,8))
plt.pie(booking_percentage, labels=booking_percentage.index, autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral', 'lightpink', 'lightsalmon'])
plt.title('Distribution of Booked Days by Neighborhood Group on Airbnb')
plt.legend(title='Neighborhood Group', bbox_to_anchor=(1, 0.5), loc="center left", borderaxespad=0.)
plt.show()
## the highest_booking_neighborhood from chart is 'Manhattan'

# %% [markdown]
# ## Task 5b: Data Visualization (Any Tool)
#
# * Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences
# * Using a line graph show in which year the maximum construction of rooms took place.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
plt.scatter(df['service_fee'], df['price'], color='coral')
plt.title('Relationship Between Service Price and Room Price on Airbnb')
plt.xlabel('Service Price')
plt.ylabel('Room Price')
# Out:
# Text(0, 0.5, 'Room Price')

# %%
plt.figure(figsize=(15, 6))
plt.plot(df['construction_year'].value_counts().sort_index().index,df['construction_year'].value_counts().sort_index().values, marker='o', linestyle='-', color='skyblue')
plt.title('Relationship Between Service Price and Room Price on Airbnb')
plt.xlabel('construction_ye')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## Task 5c: Data Visualization (Any Tool)
#
# * With the help of box plots illustrate the following
#  * Effect of Review Rate number on price
#  * Effect of host identity verified on price
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
plt.boxplot([df[df['review_rate_number'] == rate]['price'] for rate in df['review_rate_number'].unique()], labels=df['review_rate_number'].unique())
plt.title('Effect of Review Rate on Price on Airbnb')
plt.xlabel('Review Rate')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.boxplot([df[df['host_identity_verified'] == status]['price'] for status in df['host_identity_verified'].unique()],
            labels=df['host_identity_verified'].unique())
plt.title('Effect of Host Identity Verification on Price on Airbnb')
plt.xlabel('Host Identity Verified')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
